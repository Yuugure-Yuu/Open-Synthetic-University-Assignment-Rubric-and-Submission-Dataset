# %%
import pandas as pd
import csv
import sys
import os
import importlib
# sys.path.append(os.path.dirname(__file__))
from cohmetrixEN import run_coh_metrix
import warnings
warnings.filterwarnings('ignore')

import logging
logging.getLogger().setLevel(logging.ERROR)

# 关闭 IPython 的警告显示
from IPython.display import display
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")
# Out:
# WARNING:root:failed to load projection from C:\Users\kqia0008\D\Coh-MetrixEN\cohmetrixEN\..\resources\lsi_wiki.model.projection: [Errno 2] No such file or directory: 'C:\\Users\\kqia0008\\D\\Coh-MetrixEN\\cohmetrixEN\\..\\resources\\lsi_wiki.model.projection.u.npy'

# %%
# forum = pd.read_csv('BancoCompletoEN.csv')[:3]

forum = pd.read_csv('resemblance.csv', header=0)

# %%
forum = pd.read_csv('../Dean/Data/FIT2021 S1/300resemblance.csv', header=0)

# %%
forum = forum[['unit_name','assignment_name','Assignment description','Real student submission name','Real student submission','Virtual assignment description','Virtual student submission']]

# %%
df1 = pd.read_csv('../Dean/Data/FIT2021 S1/resemblance.csv', header=0)
df2 = pd.read_csv('../Dean/Data/FIT2021 S1/300resemblance.csv', header=0)

df1 = df1[['unit_name','assignment_name','Assignment description','Real student submission name','Real student submission','Virtual assignment description','Virtual student submission']]
df2 = df2[['unit_name','assignment_name','Assignment description','Real student submission name','Real student submission','Virtual assignment description','Virtual student submission']]

df_concat = pd.concat([df1, df2], ignore_index=True)

# %%
df_concat.to_csv('resemblance.csv', index=False)

# %%
df1 = pd.read_csv('resemblance[\'Real student submission\'].csv', header=0)[:200]
df2 = pd.read_csv('new_resemblance[\'Real student submission\'].csv', header=0)

df_concat = pd.concat([df1, df2], ignore_index=True).reset_index()
df_concat.to_csv('new_resemblance[\'Real student submission\'].csv', index=False)

# %%
# forum.to_csv('200resemblance.csv', index=False)

# %%
forum.columns
# Out:
# Index(['unit_name', 'assignment_name', 'Assignment description',
#        'Real student submission name', 'Real student submission',
#        'Virtual assignment description', 'Virtual student submission'],
#       dtype='object')

# %%
df1 = pd.read_csv('resemblance[\'Virtual student submission\'].csv', header=0)[:200]
df2 = pd.read_csv('new_resemblance[\'Virtual student submission\'].csv', header=0)

# %%
df2
# Out:
#      index                                          unit_name  \
# 0        0    FIT1006 Business information analysis - S1 2021
# 1        1     FIT1043 Introduction to data science - S1 2021
# 2        2     FIT1043 Introduction to data science - S1 2021
# 3        3     FIT1043 Introduction to data science - S1 2021
# 4        4  FIT1047 Introduction to computer systems, netw...
# ..     ...                                                ...
# 495    495  FIT9136 Algorithms and programming foundations...
# 496    496  FIT9136 Algorithms and programming foundations...
# 497    497  FIT9136 Algorithms and programming foundations...
# 498    498  FIT9136 Algorithms and programming foundations...
# 499    499  FIT9137 Introduction to computer architecture ...
#
#                                        assignment_name  \
# 0    FIT1006_S1_2021-FIT1006 Written Assignment (We...
# 1         FIT1043_S1_2021-Assessment 1 Hand-in-8284483
# ...

# %%
# %%time

with open('new_resemblance[\'Real student submission\'].csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["unit_name", "assignment_name", "Real student submission name", "Real student submission", "cm.DESPC","cm.DESSC","cm.DESWC","cm.DESPL","cm.DESPLd","cm.DESSL","cm.DESSLd","cm.DESWLsy","cm.DESWLsyd","cm.DESWLlt","cm.DESWLltd",
                     "cm.CRFNO1","cm.CRFAO1","cm.CRFSO1","cm.CRFNOa","cm.CRFAOa","cm.CRFSOa","cm.CRFCWO1","cm.CRFCWO1d","cm.CRFCWOa","cm.CRFCWOad","cm.CRFANP1","cm.CRFANPa",
                     "cm.LSASS1","cm.LSASS1d","cm.LSASSp","cm.LSASSpd", "cm.LSAPP1","cm.LSAPP1d","cm.LSAGN","cm.LSAGNd",
                     "cm.LDTTRc","cm.LDTTRa","cm.LDMTLDa","cm.LDVOCDa",
                     "cm.CNCAll","cm.CNCCaus","cm.CNCLogic","cm.CNCADC","cm.CNCTemp","cm.CNCAdd","cm.CNCPos", "cm.CNCNeg",
                     "cm.SMCAUSv","cm.SMCAUSvp","cm.SMCAUSr","cm.SMCAUSlsa","cm.SMCAUSwn",
                     "cm.SYNLE","cm.SYNMEDpos","cm.SYNMEDwrd","cm.SYNMEDlem","cm.SYNSTRUTa","cm.SYNSTRUTt",
                     "cm.DRNP","cm.DRVP","cm.DRAP","cm.DRPP","cm.DRPVAL","cm.DRNEG","cm.DRGERUND","cm.DRINF",
                     "cm.WRDNOUN","cm.WRDVERB","cm.WRDADJ","cm.WRDADV","cm.WRDPRO","cm.WRDPRP1s",
                     "cm.WRDPRP1p","cm.WRDPRP2","cm.WRDPRP3s","cm.WRDPRP3p","cm.WRDFRQc","cm.WRDFRQa","cm.WRDFRQmc",
                     "cm.WRDAOAc","cm.WRDFAMc","cm.WRDCNCc","cm.WRDIMGc","cm.WRDMEAc",
                     "cm.RDFRE","cm.RDFKGL","cm.RDL2"])



    for index, row in forum.iterrows():
        print(index)
        #print(liwc.liwcFeatures(r))
        result_cohmetrix = run_coh_metrix.coh_metrix_features(row['Real student submission'])

        writer.writerow([row['unit_name'],row['assignment_name'],row['Real student submission name'],row['Real student submission'],result_cohmetrix[0],result_cohmetrix[1],result_cohmetrix[2],result_cohmetrix[3],result_cohmetrix[4]
                         ,result_cohmetrix[5],result_cohmetrix[6],result_cohmetrix[7],result_cohmetrix[8],result_cohmetrix[9]
                         ,result_cohmetrix[10],result_cohmetrix[11],result_cohmetrix[12],result_cohmetrix[13],result_cohmetrix[14]
                         ,result_cohmetrix[15],result_cohmetrix[16],result_cohmetrix[17],result_cohmetrix[18],result_cohmetrix[19]
                         ,result_cohmetrix[20],result_cohmetrix[21],result_cohmetrix[22],result_cohmetrix[23],result_cohmetrix[24]
                         ,result_cohmetrix[25],result_cohmetrix[26],result_cohmetrix[27],result_cohmetrix[28],result_cohmetrix[29]
                         ,result_cohmetrix[30],result_cohmetrix[31],result_cohmetrix[32],result_cohmetrix[33],result_cohmetrix[34]
                         ,result_cohmetrix[35],result_cohmetrix[36],result_cohmetrix[37],result_cohmetrix[38],result_cohmetrix[39]
                         ,result_cohmetrix[40],result_cohmetrix[41],result_cohmetrix[42],result_cohmetrix[43],result_cohmetrix[44]
                         ,result_cohmetrix[45],result_cohmetrix[46],result_cohmetrix[47],result_cohmetrix[48],result_cohmetrix[49]
                         ,result_cohmetrix[50],result_cohmetrix[51],result_cohmetrix[52],result_cohmetrix[53],result_cohmetrix[54]
                         ,result_cohmetrix[55],result_cohmetrix[56],result_cohmetrix[57],result_cohmetrix[58],result_cohmetrix[59]
                         ,result_cohmetrix[60],result_cohmetrix[61],result_cohmetrix[62],result_cohmetrix[63],result_cohmetrix[64]
                         ,result_cohmetrix[65],result_cohmetrix[66],result_cohmetrix[67],result_cohmetrix[68],result_cohmetrix[69]
                         ,result_cohmetrix[70],result_cohmetrix[71],result_cohmetrix[72],result_cohmetrix[73],result_cohmetrix[74]
                         ,result_cohmetrix[75],result_cohmetrix[76],result_cohmetrix[77],result_cohmetrix[78],result_cohmetrix[79]
                         ,result_cohmetrix[80],result_cohmetrix[81],result_cohmetrix[82]])
# Out:
# 0
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# 1
# ...

# %%
# %%time

with open('new_resemblance[\'Virtual student submission\'].csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["unit_name", "assignment_name", "Real student submission name", "Virtual student submission", "cm.DESPC","cm.DESSC","cm.DESWC","cm.DESPL","cm.DESPLd","cm.DESSL","cm.DESSLd","cm.DESWLsy","cm.DESWLsyd","cm.DESWLlt","cm.DESWLltd",
                     "cm.CRFNO1","cm.CRFAO1","cm.CRFSO1","cm.CRFNOa","cm.CRFAOa","cm.CRFSOa","cm.CRFCWO1","cm.CRFCWO1d","cm.CRFCWOa","cm.CRFCWOad","cm.CRFANP1","cm.CRFANPa",
                     "cm.LSASS1","cm.LSASS1d","cm.LSASSp","cm.LSASSpd", "cm.LSAPP1","cm.LSAPP1d","cm.LSAGN","cm.LSAGNd",
                     "cm.LDTTRc","cm.LDTTRa","cm.LDMTLDa","cm.LDVOCDa",
                     "cm.CNCAll","cm.CNCCaus","cm.CNCLogic","cm.CNCADC","cm.CNCTemp","cm.CNCAdd","cm.CNCPos", "cm.CNCNeg",
                     "cm.SMCAUSv","cm.SMCAUSvp","cm.SMCAUSr","cm.SMCAUSlsa","cm.SMCAUSwn",
                     "cm.SYNLE","cm.SYNMEDpos","cm.SYNMEDwrd","cm.SYNMEDlem","cm.SYNSTRUTa","cm.SYNSTRUTt",
                     "cm.DRNP","cm.DRVP","cm.DRAP","cm.DRPP","cm.DRPVAL","cm.DRNEG","cm.DRGERUND","cm.DRINF",
                     "cm.WRDNOUN","cm.WRDVERB","cm.WRDADJ","cm.WRDADV","cm.WRDPRO","cm.WRDPRP1s",
                     "cm.WRDPRP1p","cm.WRDPRP2","cm.WRDPRP3s","cm.WRDPRP3p","cm.WRDFRQc","cm.WRDFRQa","cm.WRDFRQmc",
                     "cm.WRDAOAc","cm.WRDFAMc","cm.WRDCNCc","cm.WRDIMGc","cm.WRDMEAc",
                     "cm.RDFRE","cm.RDFKGL","cm.RDL2"])



    for index, row in forum.iterrows():
        print(index)
        #print(liwc.liwcFeatures(r))
        result_cohmetrix = run_coh_metrix.coh_metrix_features(row['Virtual student submission'])

        writer.writerow([row['unit_name'],row['assignment_name'],row['Real student submission name'],row['Virtual student submission'],result_cohmetrix[0],result_cohmetrix[1],result_cohmetrix[2],result_cohmetrix[3],result_cohmetrix[4]
                         ,result_cohmetrix[5],result_cohmetrix[6],result_cohmetrix[7],result_cohmetrix[8],result_cohmetrix[9]
                         ,result_cohmetrix[10],result_cohmetrix[11],result_cohmetrix[12],result_cohmetrix[13],result_cohmetrix[14]
                         ,result_cohmetrix[15],result_cohmetrix[16],result_cohmetrix[17],result_cohmetrix[18],result_cohmetrix[19]
                         ,result_cohmetrix[20],result_cohmetrix[21],result_cohmetrix[22],result_cohmetrix[23],result_cohmetrix[24]
                         ,result_cohmetrix[25],result_cohmetrix[26],result_cohmetrix[27],result_cohmetrix[28],result_cohmetrix[29]
                         ,result_cohmetrix[30],result_cohmetrix[31],result_cohmetrix[32],result_cohmetrix[33],result_cohmetrix[34]
                         ,result_cohmetrix[35],result_cohmetrix[36],result_cohmetrix[37],result_cohmetrix[38],result_cohmetrix[39]
                         ,result_cohmetrix[40],result_cohmetrix[41],result_cohmetrix[42],result_cohmetrix[43],result_cohmetrix[44]
                         ,result_cohmetrix[45],result_cohmetrix[46],result_cohmetrix[47],result_cohmetrix[48],result_cohmetrix[49]
                         ,result_cohmetrix[50],result_cohmetrix[51],result_cohmetrix[52],result_cohmetrix[53],result_cohmetrix[54]
                         ,result_cohmetrix[55],result_cohmetrix[56],result_cohmetrix[57],result_cohmetrix[58],result_cohmetrix[59]
                         ,result_cohmetrix[60],result_cohmetrix[61],result_cohmetrix[62],result_cohmetrix[63],result_cohmetrix[64]
                         ,result_cohmetrix[65],result_cohmetrix[66],result_cohmetrix[67],result_cohmetrix[68],result_cohmetrix[69]
                         ,result_cohmetrix[70],result_cohmetrix[71],result_cohmetrix[72],result_cohmetrix[73],result_cohmetrix[74]
                         ,result_cohmetrix[75],result_cohmetrix[76],result_cohmetrix[77],result_cohmetrix[78],result_cohmetrix[79]
                         ,result_cohmetrix[80],result_cohmetrix[81],result_cohmetrix[82]])
# Out:
# 0
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# 1
# ...

# %%
# %%time

# with open('virtual_assignments[\'Assignment description\'].csv', 'w', newline='', encoding='utf-8') as file:
#     writer = csv.writer(file)
#     writer.writerow(["unit_name", "assignment_name", "Assignment description file", "Assignment description", "cm.DESPC","cm.DESSC","cm.DESWC","cm.DESPL","cm.DESPLd","cm.DESSL","cm.DESSLd","cm.DESWLsy","cm.DESWLsyd","cm.DESWLlt","cm.DESWLltd",
#                      "cm.CRFNO1","cm.CRFAO1","cm.CRFSO1","cm.CRFNOa","cm.CRFAOa","cm.CRFSOa","cm.CRFCWO1","cm.CRFCWO1d","cm.CRFCWOa","cm.CRFCWOad","cm.CRFANP1","cm.CRFANPa",
#                      "cm.LSASS1","cm.LSASS1d","cm.LSASSp","cm.LSASSpd", "cm.LSAPP1","cm.LSAPP1d","cm.LSAGN","cm.LSAGNd",
#                      "cm.LDTTRc","cm.LDTTRa","cm.LDMTLDa","cm.LDVOCDa",
#                      "cm.CNCAll","cm.CNCCaus","cm.CNCLogic","cm.CNCADC","cm.CNCTemp","cm.CNCAdd","cm.CNCPos", "cm.CNCNeg",
#                      "cm.SMCAUSv","cm.SMCAUSvp","cm.SMCAUSr","cm.SMCAUSlsa","cm.SMCAUSwn",
#                      "cm.SYNLE","cm.SYNMEDpos","cm.SYNMEDwrd","cm.SYNMEDlem","cm.SYNSTRUTa","cm.SYNSTRUTt",
#                      "cm.DRNP","cm.DRVP","cm.DRAP","cm.DRPP","cm.DRPVAL","cm.DRNEG","cm.DRGERUND","cm.DRINF",
#                      "cm.WRDNOUN","cm.WRDVERB","cm.WRDADJ","cm.WRDADV","cm.WRDPRO","cm.WRDPRP1s",
#                      "cm.WRDPRP1p","cm.WRDPRP2","cm.WRDPRP3s","cm.WRDPRP3p","cm.WRDFRQc","cm.WRDFRQa","cm.WRDFRQmc",
#                      "cm.WRDAOAc","cm.WRDFAMc","cm.WRDCNCc","cm.WRDIMGc","cm.WRDMEAc",
#                      "cm.RDFRE","cm.RDFKGL","cm.RDL2"])



#     for index, row in forum.iterrows():
#         print(index)
#         #print(liwc.liwcFeatures(r))
#         result_cohmetrix = run_coh_metrix.coh_metrix_features(row['Assignment description'])

#         writer.writerow([row['unit_name'],row['assignment_name'],row['Assignment description file'],row['Assignment description'],result_cohmetrix[0],result_cohmetrix[1],result_cohmetrix[2],result_cohmetrix[3],result_cohmetrix[4]
#                          ,result_cohmetrix[5],result_cohmetrix[6],result_cohmetrix[7],result_cohmetrix[8],result_cohmetrix[9]
#                          ,result_cohmetrix[10],result_cohmetrix[11],result_cohmetrix[12],result_cohmetrix[13],result_cohmetrix[14]
#                          ,result_cohmetrix[15],result_cohmetrix[16],result_cohmetrix[17],result_cohmetrix[18],result_cohmetrix[19]
#                          ,result_cohmetrix[20],result_cohmetrix[21],result_cohmetrix[22],result_cohmetrix[23],result_cohmetrix[24]
#                          ,result_cohmetrix[25],result_cohmetrix[26],result_cohmetrix[27],result_cohmetrix[28],result_cohmetrix[29]
#                          ,result_cohmetrix[30],result_cohmetrix[31],result_cohmetrix[32],result_cohmetrix[33],result_cohmetrix[34]
#                          ,result_cohmetrix[35],result_cohmetrix[36],result_cohmetrix[37],result_cohmetrix[38],result_cohmetrix[39]
#                          ,result_cohmetrix[40],result_cohmetrix[41],result_cohmetrix[42],result_cohmetrix[43],result_cohmetrix[44]
#                          ,result_cohmetrix[45],result_cohmetrix[46],result_cohmetrix[47],result_cohmetrix[48],result_cohmetrix[49]
#                          ,result_cohmetrix[50],result_cohmetrix[51],result_cohmetrix[52],result_cohmetrix[53],result_cohmetrix[54]
#                          ,result_cohmetrix[55],result_cohmetrix[56],result_cohmetrix[57],result_cohmetrix[58],result_cohmetrix[59]
#                          ,result_cohmetrix[60],result_cohmetrix[61],result_cohmetrix[62],result_cohmetrix[63],result_cohmetrix[64]
#                          ,result_cohmetrix[65],result_cohmetrix[66],result_cohmetrix[67],result_cohmetrix[68],result_cohmetrix[69]
#                          ,result_cohmetrix[70],result_cohmetrix[71],result_cohmetrix[72],result_cohmetrix[73],result_cohmetrix[74]
#                          ,result_cohmetrix[75],result_cohmetrix[76],result_cohmetrix[77],result_cohmetrix[78],result_cohmetrix[79]
#                          ,result_cohmetrix[80],result_cohmetrix[81],result_cohmetrix[82]])
# Out:
# 0
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# 1
# ...

# %%
# %%time

# with open('virtual_assignments[\'Virtual assignment description\'].csv', 'w', newline='', encoding='utf-8') as file:
#     writer = csv.writer(file)
#     writer.writerow(["unit_name", "assignment_name", "Assignment description file", "Virtual assignment description", "cm.DESPC","cm.DESSC","cm.DESWC","cm.DESPL","cm.DESPLd","cm.DESSL","cm.DESSLd","cm.DESWLsy","cm.DESWLsyd","cm.DESWLlt","cm.DESWLltd",
#                      "cm.CRFNO1","cm.CRFAO1","cm.CRFSO1","cm.CRFNOa","cm.CRFAOa","cm.CRFSOa","cm.CRFCWO1","cm.CRFCWO1d","cm.CRFCWOa","cm.CRFCWOad","cm.CRFANP1","cm.CRFANPa",
#                      "cm.LSASS1","cm.LSASS1d","cm.LSASSp","cm.LSASSpd", "cm.LSAPP1","cm.LSAPP1d","cm.LSAGN","cm.LSAGNd",
#                      "cm.LDTTRc","cm.LDTTRa","cm.LDMTLDa","cm.LDVOCDa",
#                      "cm.CNCAll","cm.CNCCaus","cm.CNCLogic","cm.CNCADC","cm.CNCTemp","cm.CNCAdd","cm.CNCPos", "cm.CNCNeg",
#                      "cm.SMCAUSv","cm.SMCAUSvp","cm.SMCAUSr","cm.SMCAUSlsa","cm.SMCAUSwn",
#                      "cm.SYNLE","cm.SYNMEDpos","cm.SYNMEDwrd","cm.SYNMEDlem","cm.SYNSTRUTa","cm.SYNSTRUTt",
#                      "cm.DRNP","cm.DRVP","cm.DRAP","cm.DRPP","cm.DRPVAL","cm.DRNEG","cm.DRGERUND","cm.DRINF",
#                      "cm.WRDNOUN","cm.WRDVERB","cm.WRDADJ","cm.WRDADV","cm.WRDPRO","cm.WRDPRP1s",
#                      "cm.WRDPRP1p","cm.WRDPRP2","cm.WRDPRP3s","cm.WRDPRP3p","cm.WRDFRQc","cm.WRDFRQa","cm.WRDFRQmc",
#                      "cm.WRDAOAc","cm.WRDFAMc","cm.WRDCNCc","cm.WRDIMGc","cm.WRDMEAc",
#                      "cm.RDFRE","cm.RDFKGL","cm.RDL2"])



#     for index, row in forum.iterrows():
#         print(index)
#         #print(liwc.liwcFeatures(r))
#         result_cohmetrix = run_coh_metrix.coh_metrix_features(row['Virtual assignment description'])

#         writer.writerow([row['unit_name'],row['assignment_name'],row['Assignment description file'],row['Virtual assignment description'],result_cohmetrix[0],result_cohmetrix[1],result_cohmetrix[2],result_cohmetrix[3],result_cohmetrix[4]
#                          ,result_cohmetrix[5],result_cohmetrix[6],result_cohmetrix[7],result_cohmetrix[8],result_cohmetrix[9]
#                          ,result_cohmetrix[10],result_cohmetrix[11],result_cohmetrix[12],result_cohmetrix[13],result_cohmetrix[14]
#                          ,result_cohmetrix[15],result_cohmetrix[16],result_cohmetrix[17],result_cohmetrix[18],result_cohmetrix[19]
#                          ,result_cohmetrix[20],result_cohmetrix[21],result_cohmetrix[22],result_cohmetrix[23],result_cohmetrix[24]
#                          ,result_cohmetrix[25],result_cohmetrix[26],result_cohmetrix[27],result_cohmetrix[28],result_cohmetrix[29]
#                          ,result_cohmetrix[30],result_cohmetrix[31],result_cohmetrix[32],result_cohmetrix[33],result_cohmetrix[34]
#                          ,result_cohmetrix[35],result_cohmetrix[36],result_cohmetrix[37],result_cohmetrix[38],result_cohmetrix[39]
#                          ,result_cohmetrix[40],result_cohmetrix[41],result_cohmetrix[42],result_cohmetrix[43],result_cohmetrix[44]
#                          ,result_cohmetrix[45],result_cohmetrix[46],result_cohmetrix[47],result_cohmetrix[48],result_cohmetrix[49]
#                          ,result_cohmetrix[50],result_cohmetrix[51],result_cohmetrix[52],result_cohmetrix[53],result_cohmetrix[54]
#                          ,result_cohmetrix[55],result_cohmetrix[56],result_cohmetrix[57],result_cohmetrix[58],result_cohmetrix[59]
#                          ,result_cohmetrix[60],result_cohmetrix[61],result_cohmetrix[62],result_cohmetrix[63],result_cohmetrix[64]
#                          ,result_cohmetrix[65],result_cohmetrix[66],result_cohmetrix[67],result_cohmetrix[68],result_cohmetrix[69]
#                          ,result_cohmetrix[70],result_cohmetrix[71],result_cohmetrix[72],result_cohmetrix[73],result_cohmetrix[74]
#                          ,result_cohmetrix[75],result_cohmetrix[76],result_cohmetrix[77],result_cohmetrix[78],result_cohmetrix[79]
#                          ,result_cohmetrix[80],result_cohmetrix[81],result_cohmetrix[82]])
# Out:
# 0
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# 1
# ...

# %%
# %%time

with open('utility_dataset[\'Real assignment feedback\'].csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["unit_name", "assignment_name", "Real student submission name", "Real assignment feedback", "cm.DESPC","cm.DESSC","cm.DESWC","cm.DESPL","cm.DESPLd","cm.DESSL","cm.DESSLd","cm.DESWLsy","cm.DESWLsyd","cm.DESWLlt","cm.DESWLltd",
                     "cm.CRFNO1","cm.CRFAO1","cm.CRFSO1","cm.CRFNOa","cm.CRFAOa","cm.CRFSOa","cm.CRFCWO1","cm.CRFCWO1d","cm.CRFCWOa","cm.CRFCWOad","cm.CRFANP1","cm.CRFANPa",
                     "cm.LSASS1","cm.LSASS1d","cm.LSASSp","cm.LSASSpd", "cm.LSAPP1","cm.LSAPP1d","cm.LSAGN","cm.LSAGNd",
                     "cm.LDTTRc","cm.LDTTRa","cm.LDMTLDa","cm.LDVOCDa",
                     "cm.CNCAll","cm.CNCCaus","cm.CNCLogic","cm.CNCADC","cm.CNCTemp","cm.CNCAdd","cm.CNCPos", "cm.CNCNeg",
                     "cm.SMCAUSv","cm.SMCAUSvp","cm.SMCAUSr","cm.SMCAUSlsa","cm.SMCAUSwn",
                     "cm.SYNLE","cm.SYNMEDpos","cm.SYNMEDwrd","cm.SYNMEDlem","cm.SYNSTRUTa","cm.SYNSTRUTt",
                     "cm.DRNP","cm.DRVP","cm.DRAP","cm.DRPP","cm.DRPVAL","cm.DRNEG","cm.DRGERUND","cm.DRINF",
                     "cm.WRDNOUN","cm.WRDVERB","cm.WRDADJ","cm.WRDADV","cm.WRDPRO","cm.WRDPRP1s",
                     "cm.WRDPRP1p","cm.WRDPRP2","cm.WRDPRP3s","cm.WRDPRP3p","cm.WRDFRQc","cm.WRDFRQa","cm.WRDFRQmc",
                     "cm.WRDAOAc","cm.WRDFAMc","cm.WRDCNCc","cm.WRDIMGc","cm.WRDMEAc",
                     "cm.RDFRE","cm.RDFKGL","cm.RDL2"])



    for index, row in forum.iterrows():
        print(index)
        #print(liwc.liwcFeatures(r))
        result_cohmetrix = run_coh_metrix.coh_metrix_features(row['Real assignment feedback'])

        writer.writerow([row['unit_name'],row['assignment_name'],row['Real student submission name'],row['Real assignment feedback'],result_cohmetrix[0],result_cohmetrix[1],result_cohmetrix[2],result_cohmetrix[3],result_cohmetrix[4]
                         ,result_cohmetrix[5],result_cohmetrix[6],result_cohmetrix[7],result_cohmetrix[8],result_cohmetrix[9]
                         ,result_cohmetrix[10],result_cohmetrix[11],result_cohmetrix[12],result_cohmetrix[13],result_cohmetrix[14]
                         ,result_cohmetrix[15],result_cohmetrix[16],result_cohmetrix[17],result_cohmetrix[18],result_cohmetrix[19]
                         ,result_cohmetrix[20],result_cohmetrix[21],result_cohmetrix[22],result_cohmetrix[23],result_cohmetrix[24]
                         ,result_cohmetrix[25],result_cohmetrix[26],result_cohmetrix[27],result_cohmetrix[28],result_cohmetrix[29]
                         ,result_cohmetrix[30],result_cohmetrix[31],result_cohmetrix[32],result_cohmetrix[33],result_cohmetrix[34]
                         ,result_cohmetrix[35],result_cohmetrix[36],result_cohmetrix[37],result_cohmetrix[38],result_cohmetrix[39]
                         ,result_cohmetrix[40],result_cohmetrix[41],result_cohmetrix[42],result_cohmetrix[43],result_cohmetrix[44]
                         ,result_cohmetrix[45],result_cohmetrix[46],result_cohmetrix[47],result_cohmetrix[48],result_cohmetrix[49]
                         ,result_cohmetrix[50],result_cohmetrix[51],result_cohmetrix[52],result_cohmetrix[53],result_cohmetrix[54]
                         ,result_cohmetrix[55],result_cohmetrix[56],result_cohmetrix[57],result_cohmetrix[58],result_cohmetrix[59]
                         ,result_cohmetrix[60],result_cohmetrix[61],result_cohmetrix[62],result_cohmetrix[63],result_cohmetrix[64]
                         ,result_cohmetrix[65],result_cohmetrix[66],result_cohmetrix[67],result_cohmetrix[68],result_cohmetrix[69]
                         ,result_cohmetrix[70],result_cohmetrix[71],result_cohmetrix[72],result_cohmetrix[73],result_cohmetrix[74]
                         ,result_cohmetrix[75],result_cohmetrix[76],result_cohmetrix[77],result_cohmetrix[78],result_cohmetrix[79]
                         ,result_cohmetrix[80],result_cohmetrix[81],result_cohmetrix[82]])
# Out:
# 0
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# 1
# ...

# %%
forum = pd.read_csv('../Dean/Data/FIT2021 S1/utility_dataset[\'Virtual assignment feedback\'].csv', header=0)

# %%
# %%time

with open('utility_dataset[\'Virtual assignment feedback\'].csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["unit_name", "assignment_name", "Real student submission name", "Virtual assignment feedback", "cm.DESPC","cm.DESSC","cm.DESWC","cm.DESPL","cm.DESPLd","cm.DESSL","cm.DESSLd","cm.DESWLsy","cm.DESWLsyd","cm.DESWLlt","cm.DESWLltd",
                     "cm.CRFNO1","cm.CRFAO1","cm.CRFSO1","cm.CRFNOa","cm.CRFAOa","cm.CRFSOa","cm.CRFCWO1","cm.CRFCWO1d","cm.CRFCWOa","cm.CRFCWOad","cm.CRFANP1","cm.CRFANPa",
                     "cm.LSASS1","cm.LSASS1d","cm.LSASSp","cm.LSASSpd", "cm.LSAPP1","cm.LSAPP1d","cm.LSAGN","cm.LSAGNd",
                     "cm.LDTTRc","cm.LDTTRa","cm.LDMTLDa","cm.LDVOCDa",
                     "cm.CNCAll","cm.CNCCaus","cm.CNCLogic","cm.CNCADC","cm.CNCTemp","cm.CNCAdd","cm.CNCPos", "cm.CNCNeg",
                     "cm.SMCAUSv","cm.SMCAUSvp","cm.SMCAUSr","cm.SMCAUSlsa","cm.SMCAUSwn",
                     "cm.SYNLE","cm.SYNMEDpos","cm.SYNMEDwrd","cm.SYNMEDlem","cm.SYNSTRUTa","cm.SYNSTRUTt",
                     "cm.DRNP","cm.DRVP","cm.DRAP","cm.DRPP","cm.DRPVAL","cm.DRNEG","cm.DRGERUND","cm.DRINF",
                     "cm.WRDNOUN","cm.WRDVERB","cm.WRDADJ","cm.WRDADV","cm.WRDPRO","cm.WRDPRP1s",
                     "cm.WRDPRP1p","cm.WRDPRP2","cm.WRDPRP3s","cm.WRDPRP3p","cm.WRDFRQc","cm.WRDFRQa","cm.WRDFRQmc",
                     "cm.WRDAOAc","cm.WRDFAMc","cm.WRDCNCc","cm.WRDIMGc","cm.WRDMEAc",
                     "cm.RDFRE","cm.RDFKGL","cm.RDL2"])



    for index, row in forum.iterrows():
        print(index)
        #print(liwc.liwcFeatures(r))
        result_cohmetrix = run_coh_metrix.coh_metrix_features(row['Virtual assignment feedback'])

        writer.writerow([row['unit_name'],row['assignment_name'],row['Real student submission name'],row['Virtual assignment feedback'],result_cohmetrix[0],result_cohmetrix[1],result_cohmetrix[2],result_cohmetrix[3],result_cohmetrix[4]
                         ,result_cohmetrix[5],result_cohmetrix[6],result_cohmetrix[7],result_cohmetrix[8],result_cohmetrix[9]
                         ,result_cohmetrix[10],result_cohmetrix[11],result_cohmetrix[12],result_cohmetrix[13],result_cohmetrix[14]
                         ,result_cohmetrix[15],result_cohmetrix[16],result_cohmetrix[17],result_cohmetrix[18],result_cohmetrix[19]
                         ,result_cohmetrix[20],result_cohmetrix[21],result_cohmetrix[22],result_cohmetrix[23],result_cohmetrix[24]
                         ,result_cohmetrix[25],result_cohmetrix[26],result_cohmetrix[27],result_cohmetrix[28],result_cohmetrix[29]
                         ,result_cohmetrix[30],result_cohmetrix[31],result_cohmetrix[32],result_cohmetrix[33],result_cohmetrix[34]
                         ,result_cohmetrix[35],result_cohmetrix[36],result_cohmetrix[37],result_cohmetrix[38],result_cohmetrix[39]
                         ,result_cohmetrix[40],result_cohmetrix[41],result_cohmetrix[42],result_cohmetrix[43],result_cohmetrix[44]
                         ,result_cohmetrix[45],result_cohmetrix[46],result_cohmetrix[47],result_cohmetrix[48],result_cohmetrix[49]
                         ,result_cohmetrix[50],result_cohmetrix[51],result_cohmetrix[52],result_cohmetrix[53],result_cohmetrix[54]
                         ,result_cohmetrix[55],result_cohmetrix[56],result_cohmetrix[57],result_cohmetrix[58],result_cohmetrix[59]
                         ,result_cohmetrix[60],result_cohmetrix[61],result_cohmetrix[62],result_cohmetrix[63],result_cohmetrix[64]
                         ,result_cohmetrix[65],result_cohmetrix[66],result_cohmetrix[67],result_cohmetrix[68],result_cohmetrix[69]
                         ,result_cohmetrix[70],result_cohmetrix[71],result_cohmetrix[72],result_cohmetrix[73],result_cohmetrix[74]
                         ,result_cohmetrix[75],result_cohmetrix[76],result_cohmetrix[77],result_cohmetrix[78],result_cohmetrix[79]
                         ,result_cohmetrix[80],result_cohmetrix[81],result_cohmetrix[82]])
# Out:
# 0
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# C:\Users\kqia0008\AppData\Local\anaconda3\envs\py39\lib\site-packages\textacy\extract.py:328: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   utils.deprecated(
# 1
# ...

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                   C:\Users\kqia0008\AppData\Local\anaconda3
# py37                   C:\Users\kqia0008\AppData\Local\anaconda3\envs\py37
# py38                 * C:\Users\kqia0008\AppData\Local\anaconda3\envs\py38

# %%
# !pip install "setuptools<58.0.0" wheel
# Out:
# ...
#   Using cached setuptools-57.5.0-py3-none-any.whl.metadata (4.9 kB)
# ...
# Using cached setuptools-57.5.0-py3-none-any.whl (819 kB)
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
# ...

# %%
# !pip install "spacy<3.0.0"
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
# ...

# %%
# !pip install neuralcoref --no-binary neuralcoref --no-build-isolation
# Out:
# ...
#   Using cached neuralcoref-4.0.tar.gz (368 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
# ...
#    ---------------------------------------- 0.0/13.5 MB ? eta -:--:--
#    -------- ------------------------------- 2.9/13.5 MB 16.8 MB/s eta 0:00:01
#    ------------------------- -------------- 8.7/13.5 MB 22.4 MB/s eta 0:00:01
#    ---------------------------------------- 13.5/13.5 MB 24.2 MB/s eta 0:00:00
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# ...
# Using cached urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
# ...
#   Created wheel for neuralcoref: filename=neuralcoref-4.0-cp38-cp38-win_amd64.whl size=263462 sha256=04226813d78571b980b03a1960387e1706bfa24ae658faee2ab13471c3bf6563
# ...

# %%
# !pip show neuralcoref
# Out:
# Name: neuralcoref
# Version: 4.0
# Summary: Coreference Resolution in spaCy with Neural Networks
# Home-page: https://github.com/huggingface/neuralcoref
# Author: Thomas Wolf
# Author-email: thomwolf@gmail.com
# License: MIT
# Location: c:\users\kqia0008\appdata\local\anaconda3\envs\py38\lib\site-packages
# Requires: boto3, numpy, requests, spacy
# Required-by:

# %%
# !pip install dist/cohmetrixEN-0.0.1-py3-none-any.whl
# Out:
# Processing c:\users\kqia0008\d\coh-metrixen\dist\cohmetrixen-0.0.1-py3-none-any.whl
# ...
#   Using cached Pyphen-0.9.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached gensim-3.6.0.tar.gz (23.1 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached lexical_diversity-0.1.1-py3-none-any.whl.metadata (4.1 kB)
# ...
#      ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#      ----------------------------- ---------- 1.0/1.4 MB 12.7 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.0/1.4 MB 12.7 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.0/1.4 MB 12.7 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.0/1.4 MB 12.7 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.0/1.4 MB 12.7 MB/s eta 0:00:01
#      ---------------------------------------- 1.4/1.4 MB 985.6 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
# ...
